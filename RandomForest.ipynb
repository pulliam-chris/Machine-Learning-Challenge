# %%
import pandas as pd

df = pd.read_csv("data\exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
target = df['koi_disposition']
target_names = ['CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE', 'NOT DISPOSITIONED' ]

# %%
data = df.drop('koi_disposition', axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.897025171624714

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10532986406292687, 'koi_fpflag_co'),
#  (0.09799025913895168, 'koi_fpflag_nt'),
#  (0.0665844082061408, 'koi_fpflag_ss'),
#  (0.05607116598533464, 'koi_model_snr'),
#  (0.04334887546888214, 'koi_prad'),
#  (0.037161188948915874, 'koi_fpflag_ec'),
#  (0.03646465865719935, 'koi_prad_err1'),
#  (0.03545222994524972, 'koi_duration_err1'),
#  (0.03228312827763226, 'koi_steff_err1'),
#  (0.029995709224726483, 'koi_duration_err2'),
#  (0.029583320238769327, 'koi_steff_err2'),
#  (0.026352871399229105, 'koi_prad_err2'),
#  (0.02614943947022192, 'koi_time0bk_err2'),
#  (0.024924225663842153, 'koi_time0bk_err1'),
#  (0.023227281743389356, 'koi_period'),
#  (0.022487540533470112, 'koi_depth'),
#  (0.021663391714359794, 'koi_duration'),
#  (0.020972418868387462, 'koi_insol_err1'),
#  (0.019534135173497964, 'koi_impact'),
#  (0.018197156332209488, 'koi_period_err1'),
#  (0.017606064223766663, 'koi_period_err2'),
#  (0.015153288156610182, 'koi_insol'),
#  (0.01447148467127275, 'koi_time0bk'),
#  (0.014199453586903788, 'koi_teq'),
#  (0.014126930770094581, 'koi_depth_err2'),
#  (0.013861563589873763, 'koi_depth_err1'),
#  (0.0130940695969104, 'koi_insol_err2'),
#  (0.011567536911626217, 'ra'),
#  (0.011340639428618666, 'koi_impact_err1'),
#  (0.0112150519605195, 'dec'),
#  (0.011138247414621895, 'koi_impact_err2'),
#  (0.010918015724790429, 'koi_srad_err1'),
#  (0.010429705195714052, 'koi_kepmag'),
#  (0.00985129438548516, 'koi_slogg_err2'),
#  (0.009468501218132978, 'koi_steff'),
#  (0.00930112586996735, 'koi_slogg'),
#  (0.008879731380328715, 'koi_slogg_err1'),
#  (0.008498398187498478, 'koi_srad'),
#  (0.008373814129977078, 'koi_srad_err2'),
#  (0.002731814543951022, 'koi_tce_plnt_num')]
